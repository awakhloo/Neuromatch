# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from jupyterthemes import jtplot ; jtplot.style()
import hddm
import pipeline
from glob import glob
from os import chdir ; chdir('/Users/albertwakhloo/Desktop/theoretical_neuroscience/neuromatch/steinmetz full/allData/all dat')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-74e6572bb3d3> in <module>
#       3 import matplotlib.pyplot as plt
#       4 from jupyterthemes import jtplot ; jtplot.style()
# ----> 5 import hddm
#       6 import pipeline
#       7 from glob import glob
#
# ModuleNotFoundError: No module named 'hddm'

# %%
f = glob('*')
filt = pipeline.filt(f) 
filt
# Out:
#                   Origin                abbrev  n_relevant_probes
# 0        Cori_2016-12-14       Cori_2016-12-14                1.0
# 1       Moniz_2017-05-16      Moniz_2017-05-16                1.0
# 2      Muller_2017-01-09     Muller_2017-01-09                1.0
# 3   Lederberg_2017-12-08  Lederberg_2017-12-08                2.0
# 4    Richards_2017-11-02   Richards_2017-11-02                1.0
# 5       Hench_2017-06-17      Hench_2017-06-17                3.0
# 6   Lederberg_2017-12-06  Lederberg_2017-12-06                3.0
# 7      Muller_2017-01-08     Muller_2017-01-08                0.0
# 8       Hench_2017-06-18      Hench_2017-06-18                1.0
# 9   Lederberg_2017-12-07  Lederberg_2017-12-07                2.0
# 10      Hench_2017-06-16      Hench_2017-06-16                1.0
# 11  Lederberg_2017-12-09  Lederberg_2017-12-09                2.0
# 12    Radnitz_2017-01-10    Radnitz_2017-01-10                1.0
# 13    Radnitz_2017-01-11    Radnitz_2017-01-11                1.0
# 14   Richards_2017-10-29   Richards_2017-10-29                1.0
# 15  Forssmann_2017-11-01  Forssmann_2017-11-01                2.0
# 16   Richards_2017-10-31   Richards_2017-10-31                2.0
# 17       Cori_2016-12-17       Cori_2016-12-17                0.0
# 18   Richards_2017-10-30   Richards_2017-10-30                2.0
# 19       Cori_2016-12-18       Cori_2016-12-18                1.0
# 20   Richards_2017-11-01   Richards_2017-11-01                0.0
# 21  Lederberg_2017-12-05  Lederberg_2017-12-05                2.0
# 22    Radnitz_2017-01-08    Radnitz_2017-01-08                2.0
# 23    Theiler_2017-10-11    Theiler_2017-10-11                1.0
# 24      Hench_2017-06-15      Hench_2017-06-15                1.0
# 25    Radnitz_2017-01-09    Radnitz_2017-01-09                2.0
# 26  Lederberg_2017-12-10  Lederberg_2017-12-10                0.0
# 27    Radnitz_2017-01-12    Radnitz_2017-01-12                1.0
# 28  Lederberg_2017-12-11  Lederberg_2017-12-11                1.0
# 29      Tatum_2017-12-09      Tatum_2017-12-09                1.0
# 30  Forssmann_2017-11-02  Forssmann_2017-11-02                1.0
# 31  Forssmann_2017-11-05  Forssmann_2017-11-05                0.0
# 32  Forssmann_2017-11-04  Forssmann_2017-11-04                1.0
# 33      Tatum_2017-12-06      Tatum_2017-12-06                3.0
# 34      Tatum_2017-12-08      Tatum_2017-12-08                2.0

# %%
subset = filt[filt.n_relevant_probes >= 2].Origin
neur, stim = pipeline.processer(subset, truncate = 500, mr_clean = True)
# Out:
# Mapping neurons from Lederberg_2017-12-08 to channels ...
# Mapping channels to brain areas ...
# Mapping neurons from Hench_2017-06-17 to channels ...
# Mapping channels to brain areas ...
# Mapping neurons from Lederberg_2017-12-06 to channels ...
# Mapping channels to brain areas ...
# Mapping neurons from Lederberg_2017-12-07 to channels ...
# Mapping channels to brain areas ...
# Mapping neurons from Lederberg_2017-12-09 to channels ...
# Mapping channels to brain areas ...
# Mapping neurons from Forssmann_2017-11-01 to channels ...
# Mapping channels to brain areas ...
# Mapping neurons from Richards_2017-10-31 to channels ...
# Mapping channels to brain areas ...
# Mapping neurons from Richards_2017-10-30 to channels ...
# Mapping channels to brain areas ...
# Mapping neurons from Lederberg_2017-12-05 to channels ...
# Mapping channels to brain areas ...
# Mapping neurons from Radnitz_2017-01-08 to channels ...
# Mapping channels to brain areas ...
# Mapping neurons from Radnitz_2017-01-09 to channels ...
# Mapping channels to brain areas ...
# Mapping neurons from Tatum_2017-12-06 to channels ...
# Mapping channels to brain areas ...
# Mapping neurons from Tatum_2017-12-08 to channels ...
# Mapping channels to brain areas ...
# Getting behavioral data ...
# /Users/albertwakhloo/opt/miniconda3/envs/pd1hddm36/lib/python3.6/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# ~~~ OOOoOOOOooOoOOOOOOOOOOoooOooOOOOOOo ~~~

# %%
subset = neur[neur.area == 'MRN'].copy()
subset.head()
# Out:
#           spike_t area maus  neuron
# 2065921  1.816552  MRN    1  1146.0
# 2065954  1.825486  MRN    1   793.0
# 2065978  1.830619  MRN    1   709.0
# 2065994  1.834386  MRN    1  1134.0
# 2066016  1.841019  MRN    1  1041.0

# %%
dat = extract_trial_stim_avg(subset, stim, ['MRN'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-130cae72a31d> in <module>
# ----> 1 dat = extract_trial_stim_avg(subset, stim, ['MRN'])
#
# NameError: name 'extract_trial_stim_avg' is not defined

# %%
dat.head()
# Out:
#           MRN  maus
# 0    3.150685     1
# 1    3.835616     1
# 2    3.835616     1
# 3    3.561644     1
# 4    4.657534     1
# ..        ...   ...
# 355  6.105991    10
# 356  5.506912    10
# 357  6.082949    10
# 358  5.161290    10
# 359  5.783410    10
#
# [360 rows x 2 columns]

# %%
mice = stim[stim.subj_idx.isin(subset.maus.unique())].copy()
mice['raphe'] = dat.MRN.values
mice.head()
# Out:
# /Users/albertwakhloo/opt/miniconda3/envs/pd1hddm36/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            rt  subj_idx  response  response_type  split_by  feedback  q_init  \
# 102  0.850353       1.0         1            1.0         0       0.0     0.7
# 104  1.066991       1.0         1            1.0         0       0.0     0.7
# 105  1.333324       1.0         1            1.0         0       0.0     0.7
# 107  1.150106       1.0         0           -1.0         0       1.0     0.7
# 110  0.916821       1.0         1            1.0         1       1.0     0.7
#
#        stimtime     raphe
# 102   70.905798  3.150685
# 104   78.538722  3.835616
# 105   82.571988  3.835616
# 107   89.538101  3.561644
# 110  100.254276  4.657534

# %%
for i, dat in mice.groupby('subj_idx').rt : 
    dat.hist(bins = 15, alpha = 0.5)

# %%
m = hddm.HDDMrlRegressor(mice, 'v ~ raphe', include = 'alpha')
m.find_starting_values()
m.sample(1500, burn = 500)
# Out:
# Adding these covariates:
# ['v_Intercept', 'v_raphe']
# /Users/albertwakhloo/opt/miniconda3/envs/pd1hddm36/lib/python3.6/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /Users/albertwakhloo/opt/miniconda3/envs/pd1hddm36/lib/python3.6/site-packages/scipy/optimize/optimize.py:2117: RuntimeWarning: invalid value encountered in double_scalars
#   p = (x - v) * tmp2 - (x - w) * tmp1
#  [-----------------100%-----------------] 1501 of 1500 complete in 2079.9 sec

# %%
def plot_posterior(param, trace, bins = 50) : 
    _, ax = plt.subplots(1, 2, figsize = (20, 7))
    x = np.arange(len(trace))
    ax[0].hist(trace[param], bins = bins)
    ax[1].plot(x, trace[param])
trace = m.get_group_traces()

# %%
plot_posterior('v_Intercept', trace)

# %%
plot_posterior('v_raphe', trace)

# %%
plot_posterior('a', trace)

# %%
plot_posterior('t', trace)

# %%
m.get_group_nodes()
# Out:
#               knode_name stochastic observed   subj         node tag depends  \
# a                      a       True    False  False            a  ()      []
# t                      t       True    False  False            t  ()      []
# alpha              alpha       True    False  False        alpha  ()      []
# v_Intercept  v_Intercept       True    False  False  v_Intercept  ()      []
# v_striate      v_striate       True    False  False    v_striate  ()      []
#
#             hidden Unnamed: 0   rt  ... stimtime striate      mean  \
# a            False        NaN  NaN  ...      NaN     NaN   1.23095
# t            False        NaN  NaN  ...      NaN     NaN  0.477152
# alpha        False        NaN  NaN  ...      NaN     NaN   27.2638
# v_Intercept  False        NaN  NaN  ...      NaN     NaN  0.361617
# v_striate    False        NaN  NaN  ...      NaN     NaN   2.58006
#
#                     std       2.5q       25q       50q       75q     97.5q  \
# a             0.0566991    1.12888   1.19264   1.22667   1.26994   1.34751
# t            0.00729035   0.460442  0.472917  0.477972  0.482186  0.489585
# alpha           31.5195   -4.04767  0.423702   18.6556   44.2442   106.827
# v_Intercept     2.74329   -5.67277  -1.24623  0.595153   2.07563   5.65896
# v_striate       6.34816 -0.0369166  0.481303  0.834372   1.46004   25.2344
#
#                   mc err
# a             0.00253273
# t            0.000301477
# alpha            2.09386
# v_Intercept      0.22802
# v_striate        0.60289
#
# [5 rows x 26 columns]
